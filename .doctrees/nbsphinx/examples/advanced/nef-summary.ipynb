# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="487115249" href="javascript:toggle_input_487115249()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_487115249;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_487115249 = document.getElementById("487115249");
#                 var cell = link_487115249;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_487115249;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_487115249 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_487115249 = cell.previousElementSibling;
#                 }
#                 input_487115249.style.display = "none"; // hide
#
#                 toggle_input_487115249 = function() {
#                     if (input_487115249.style.display == "none") {
#                         input_487115249.style.display = ""; // show
#                         link_487115249.innerHTML = "Hide Input";
#                     } else {
#                         input_487115249.style.display = "none"; // hide
#                         link_487115249.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_487115249 = $("a[id='487115249']");
#                 var cell_487115249 = link_487115249.parents("div.cell:first");
#                 if (cell_487115249.length == 0) {
#                     cell_487115249 = link_487115249.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_487115249 = cell_487115249.children("div.input");
#                 if (input_487115249.length == 0) {
#                     input_487115249 = cell_487115249.prev("div.nbinput");
#                 }
#                 input_487115249.hide();
#
#                 toggle_input_487115249 = function() {
#                     if (input_487115249.is(':hidden')) {
#                         input_487115249.slideDown();
#                         link_487115249[0].innerHTML = "Hide Input";
#                     } else {
#                         input_487115249.slideUp();
#                         link_487115249[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1489798008" href="javascript:toggle_input_1489798008()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1489798008;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1489798008 = document.getElementById("1489798008");
#                 var cell = link_1489798008;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1489798008;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1489798008 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1489798008 = cell.previousElementSibling;
#                 }
#                 input_1489798008.style.display = "none"; // hide
#
#                 toggle_input_1489798008 = function() {
#                     if (input_1489798008.style.display == "none") {
#                         input_1489798008.style.display = ""; // show
#                         link_1489798008.innerHTML = "Hide Input";
#                     } else {
#                         input_1489798008.style.display = "none"; // hide
#                         link_1489798008.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1489798008 = $("a[id='1489798008']");
#                 var cell_1489798008 = link_1489798008.parents("div.cell:first");
#                 if (cell_1489798008.length == 0) {
#                     cell_1489798008 = link_1489798008.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1489798008 = cell_1489798008.children("div.input");
#                 if (input_1489798008.length == 0) {
#                     input_1489798008 = cell_1489798008.prev("div.nbinput");
#                 }
#                 input_1489798008.hide();
#
#                 toggle_input_1489798008 = function() {
#                     if (input_1489798008.is(':hidden')) {
#                         input_1489798008.slideDown();
#                         link_1489798008[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1489798008.slideUp();
#                         link_1489798008[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="274069753" href="javascript:toggle_input_274069753()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_274069753;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_274069753 = document.getElementById("274069753");
#                 var cell = link_274069753;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_274069753;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_274069753 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_274069753 = cell.previousElementSibling;
#                 }
#                 input_274069753.style.display = "none"; // hide
#
#                 toggle_input_274069753 = function() {
#                     if (input_274069753.style.display == "none") {
#                         input_274069753.style.display = ""; // show
#                         link_274069753.innerHTML = "Hide Input";
#                     } else {
#                         input_274069753.style.display = "none"; // hide
#                         link_274069753.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_274069753 = $("a[id='274069753']");
#                 var cell_274069753 = link_274069753.parents("div.cell:first");
#                 if (cell_274069753.length == 0) {
#                     cell_274069753 = link_274069753.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_274069753 = cell_274069753.children("div.input");
#                 if (input_274069753.length == 0) {
#                     input_274069753 = cell_274069753.prev("div.nbinput");
#                 }
#                 input_274069753.hide();
#
#                 toggle_input_274069753 = function() {
#                     if (input_274069753.is(':hidden')) {
#                         input_274069753.slideDown();
#                         link_274069753[0].innerHTML = "Hide Input";
#                     } else {
#                         input_274069753.slideUp();
#                         link_274069753[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="332207341" href="javascript:toggle_input_332207341()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_332207341;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_332207341 = document.getElementById("332207341");
#                 var cell = link_332207341;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_332207341;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_332207341 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_332207341 = cell.previousElementSibling;
#                 }
#                 input_332207341.style.display = "none"; // hide
#
#                 toggle_input_332207341 = function() {
#                     if (input_332207341.style.display == "none") {
#                         input_332207341.style.display = ""; // show
#                         link_332207341.innerHTML = "Hide Input";
#                     } else {
#                         input_332207341.style.display = "none"; // hide
#                         link_332207341.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_332207341 = $("a[id='332207341']");
#                 var cell_332207341 = link_332207341.parents("div.cell:first");
#                 if (cell_332207341.length == 0) {
#                     cell_332207341 = link_332207341.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_332207341 = cell_332207341.children("div.input");
#                 if (input_332207341.length == 0) {
#                     input_332207341 = cell_332207341.prev("div.nbinput");
#                 }
#                 input_332207341.hide();
#
#                 toggle_input_332207341 = function() {
#                     if (input_332207341.is(':hidden')) {
#                         input_332207341.slideDown();
#                         link_332207341[0].innerHTML = "Hide Input";
#                     } else {
#                         input_332207341.slideUp();
#                         link_332207341[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="518838178" href="javascript:toggle_input_518838178()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_518838178;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_518838178 = document.getElementById("518838178");
#                 var cell = link_518838178;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_518838178;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_518838178 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_518838178 = cell.previousElementSibling;
#                 }
#                 input_518838178.style.display = "none"; // hide
#
#                 toggle_input_518838178 = function() {
#                     if (input_518838178.style.display == "none") {
#                         input_518838178.style.display = ""; // show
#                         link_518838178.innerHTML = "Hide Input";
#                     } else {
#                         input_518838178.style.display = "none"; // hide
#                         link_518838178.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_518838178 = $("a[id='518838178']");
#                 var cell_518838178 = link_518838178.parents("div.cell:first");
#                 if (cell_518838178.length == 0) {
#                     cell_518838178 = link_518838178.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_518838178 = cell_518838178.children("div.input");
#                 if (input_518838178.length == 0) {
#                     input_518838178 = cell_518838178.prev("div.nbinput");
#                 }
#                 input_518838178.hide();
#
#                 toggle_input_518838178 = function() {
#                     if (input_518838178.is(':hidden')) {
#                         input_518838178.slideDown();
#                         link_518838178[0].innerHTML = "Hide Input";
#                     } else {
#                         input_518838178.slideUp();
#                         link_518838178[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1574983843" href="javascript:toggle_input_1574983843()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1574983843;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1574983843 = document.getElementById("1574983843");
#                 var cell = link_1574983843;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1574983843;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1574983843 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1574983843 = cell.previousElementSibling;
#                 }
#                 input_1574983843.style.display = "none"; // hide
#
#                 toggle_input_1574983843 = function() {
#                     if (input_1574983843.style.display == "none") {
#                         input_1574983843.style.display = ""; // show
#                         link_1574983843.innerHTML = "Hide Input";
#                     } else {
#                         input_1574983843.style.display = "none"; // hide
#                         link_1574983843.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1574983843 = $("a[id='1574983843']");
#                 var cell_1574983843 = link_1574983843.parents("div.cell:first");
#                 if (cell_1574983843.length == 0) {
#                     cell_1574983843 = link_1574983843.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1574983843 = cell_1574983843.children("div.input");
#                 if (input_1574983843.length == 0) {
#                     input_1574983843 = cell_1574983843.prev("div.nbinput");
#                 }
#                 input_1574983843.hide();
#
#                 toggle_input_1574983843 = function() {
#                     if (input_1574983843.is(':hidden')) {
#                         input_1574983843.slideDown();
#                         link_1574983843[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1574983843.slideUp();
#                         link_1574983843[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1692465535" href="javascript:toggle_input_1692465535()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1692465535;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1692465535 = document.getElementById("1692465535");
#                 var cell = link_1692465535;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1692465535;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1692465535 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1692465535 = cell.previousElementSibling;
#                 }
#                 input_1692465535.style.display = "none"; // hide
#
#                 toggle_input_1692465535 = function() {
#                     if (input_1692465535.style.display == "none") {
#                         input_1692465535.style.display = ""; // show
#                         link_1692465535.innerHTML = "Hide Input";
#                     } else {
#                         input_1692465535.style.display = "none"; // hide
#                         link_1692465535.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1692465535 = $("a[id='1692465535']");
#                 var cell_1692465535 = link_1692465535.parents("div.cell:first");
#                 if (cell_1692465535.length == 0) {
#                     cell_1692465535 = link_1692465535.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1692465535 = cell_1692465535.children("div.input");
#                 if (input_1692465535.length == 0) {
#                     input_1692465535 = cell_1692465535.prev("div.nbinput");
#                 }
#                 input_1692465535.hide();
#
#                 toggle_input_1692465535 = function() {
#                     if (input_1692465535.is(':hidden')) {
#                         input_1692465535.slideDown();
#                         link_1692465535[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1692465535.slideUp();
#                         link_1692465535[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="377284795" href="javascript:toggle_input_377284795()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_377284795;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_377284795 = document.getElementById("377284795");
#                 var cell = link_377284795;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_377284795;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_377284795 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_377284795 = cell.previousElementSibling;
#                 }
#                 input_377284795.style.display = "none"; // hide
#
#                 toggle_input_377284795 = function() {
#                     if (input_377284795.style.display == "none") {
#                         input_377284795.style.display = ""; // show
#                         link_377284795.innerHTML = "Hide Input";
#                     } else {
#                         input_377284795.style.display = "none"; // hide
#                         link_377284795.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_377284795 = $("a[id='377284795']");
#                 var cell_377284795 = link_377284795.parents("div.cell:first");
#                 if (cell_377284795.length == 0) {
#                     cell_377284795 = link_377284795.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_377284795 = cell_377284795.children("div.input");
#                 if (input_377284795.length == 0) {
#                     input_377284795 = cell_377284795.prev("div.nbinput");
#                 }
#                 input_377284795.hide();
#
#                 toggle_input_377284795 = function() {
#                     if (input_377284795.is(':hidden')) {
#                         input_377284795.slideDown();
#                         link_377284795[0].innerHTML = "Hide Input";
#                     } else {
#                         input_377284795.slideUp();
#                         link_377284795[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1229104576" href="javascript:toggle_input_1229104576()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1229104576;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1229104576 = document.getElementById("1229104576");
#                 var cell = link_1229104576;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1229104576;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1229104576 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1229104576 = cell.previousElementSibling;
#                 }
#                 input_1229104576.style.display = "none"; // hide
#
#                 toggle_input_1229104576 = function() {
#                     if (input_1229104576.style.display == "none") {
#                         input_1229104576.style.display = ""; // show
#                         link_1229104576.innerHTML = "Hide Input";
#                     } else {
#                         input_1229104576.style.display = "none"; // hide
#                         link_1229104576.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1229104576 = $("a[id='1229104576']");
#                 var cell_1229104576 = link_1229104576.parents("div.cell:first");
#                 if (cell_1229104576.length == 0) {
#                     cell_1229104576 = link_1229104576.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1229104576 = cell_1229104576.children("div.input");
#                 if (input_1229104576.length == 0) {
#                     input_1229104576 = cell_1229104576.prev("div.nbinput");
#                 }
#                 input_1229104576.hide();
#
#                 toggle_input_1229104576 = function() {
#                     if (input_1229104576.is(':hidden')) {
#                         input_1229104576.slideDown();
#                         link_1229104576[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1229104576.slideUp();
#                         link_1229104576[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2128186355" href="javascript:toggle_input_2128186355()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2128186355;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2128186355 = document.getElementById("2128186355");
#                 var cell = link_2128186355;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2128186355;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2128186355 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2128186355 = cell.previousElementSibling;
#                 }
#                 input_2128186355.style.display = "none"; // hide
#
#                 toggle_input_2128186355 = function() {
#                     if (input_2128186355.style.display == "none") {
#                         input_2128186355.style.display = ""; // show
#                         link_2128186355.innerHTML = "Hide Input";
#                     } else {
#                         input_2128186355.style.display = "none"; // hide
#                         link_2128186355.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2128186355 = $("a[id='2128186355']");
#                 var cell_2128186355 = link_2128186355.parents("div.cell:first");
#                 if (cell_2128186355.length == 0) {
#                     cell_2128186355 = link_2128186355.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2128186355 = cell_2128186355.children("div.input");
#                 if (input_2128186355.length == 0) {
#                     input_2128186355 = cell_2128186355.prev("div.nbinput");
#                 }
#                 input_2128186355.hide();
#
#                 toggle_input_2128186355 = function() {
#                     if (input_2128186355.is(':hidden')) {
#                         input_2128186355.slideDown();
#                         link_2128186355[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2128186355.slideUp();
#                         link_2128186355[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1641271652" href="javascript:toggle_input_1641271652()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1641271652;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1641271652 = document.getElementById("1641271652");
#                 var cell = link_1641271652;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1641271652;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1641271652 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1641271652 = cell.previousElementSibling;
#                 }
#                 input_1641271652.style.display = "none"; // hide
#
#                 toggle_input_1641271652 = function() {
#                     if (input_1641271652.style.display == "none") {
#                         input_1641271652.style.display = ""; // show
#                         link_1641271652.innerHTML = "Hide Input";
#                     } else {
#                         input_1641271652.style.display = "none"; // hide
#                         link_1641271652.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1641271652 = $("a[id='1641271652']");
#                 var cell_1641271652 = link_1641271652.parents("div.cell:first");
#                 if (cell_1641271652.length == 0) {
#                     cell_1641271652 = link_1641271652.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1641271652 = cell_1641271652.children("div.input");
#                 if (input_1641271652.length == 0) {
#                     input_1641271652 = cell_1641271652.prev("div.nbinput");
#                 }
#                 input_1641271652.hide();
#
#                 toggle_input_1641271652 = function() {
#                     if (input_1641271652.is(':hidden')) {
#                         input_1641271652.slideDown();
#                         link_1641271652[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1641271652.slideUp();
#                         link_1641271652[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="214575664" href="javascript:toggle_input_214575664()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_214575664;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_214575664 = document.getElementById("214575664");
#                 var cell = link_214575664;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_214575664;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_214575664 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_214575664 = cell.previousElementSibling;
#                 }
#                 input_214575664.style.display = "none"; // hide
#
#                 toggle_input_214575664 = function() {
#                     if (input_214575664.style.display == "none") {
#                         input_214575664.style.display = ""; // show
#                         link_214575664.innerHTML = "Hide Input";
#                     } else {
#                         input_214575664.style.display = "none"; // hide
#                         link_214575664.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_214575664 = $("a[id='214575664']");
#                 var cell_214575664 = link_214575664.parents("div.cell:first");
#                 if (cell_214575664.length == 0) {
#                     cell_214575664 = link_214575664.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_214575664 = cell_214575664.children("div.input");
#                 if (input_214575664.length == 0) {
#                     input_214575664 = cell_214575664.prev("div.nbinput");
#                 }
#                 input_214575664.hide();
#
#                 toggle_input_214575664 = function() {
#                     if (input_214575664.is(':hidden')) {
#                         input_214575664.slideDown();
#                         link_214575664[0].innerHTML = "Hide Input";
#                     } else {
#                         input_214575664.slideUp();
#                         link_214575664[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="532562310" href="javascript:toggle_input_532562310()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_532562310;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_532562310 = document.getElementById("532562310");
#                 var cell = link_532562310;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_532562310;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_532562310 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_532562310 = cell.previousElementSibling;
#                 }
#                 input_532562310.style.display = "none"; // hide
#
#                 toggle_input_532562310 = function() {
#                     if (input_532562310.style.display == "none") {
#                         input_532562310.style.display = ""; // show
#                         link_532562310.innerHTML = "Hide Input";
#                     } else {
#                         input_532562310.style.display = "none"; // hide
#                         link_532562310.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_532562310 = $("a[id='532562310']");
#                 var cell_532562310 = link_532562310.parents("div.cell:first");
#                 if (cell_532562310.length == 0) {
#                     cell_532562310 = link_532562310.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_532562310 = cell_532562310.children("div.input");
#                 if (input_532562310.length == 0) {
#                     input_532562310 = cell_532562310.prev("div.nbinput");
#                 }
#                 input_532562310.hide();
#
#                 toggle_input_532562310 = function() {
#                     if (input_532562310.is(':hidden')) {
#                         input_532562310.slideDown();
#                         link_532562310[0].innerHTML = "Hide Input";
#                     } else {
#                         input_532562310.slideUp();
#                         link_532562310[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
