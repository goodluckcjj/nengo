# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1560397416" href="javascript:toggle_input_1560397416()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1560397416;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1560397416 = document.getElementById("1560397416");
#                 var cell = link_1560397416;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1560397416;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1560397416 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1560397416 = cell.previousElementSibling;
#                 }
#                 input_1560397416.style.display = "none"; // hide
#
#                 toggle_input_1560397416 = function() {
#                     if (input_1560397416.style.display == "none") {
#                         input_1560397416.style.display = ""; // show
#                         link_1560397416.innerHTML = "Hide Input";
#                     } else {
#                         input_1560397416.style.display = "none"; // hide
#                         link_1560397416.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1560397416 = $("a[id='1560397416']");
#                 var cell_1560397416 = link_1560397416.parents("div.cell:first");
#                 if (cell_1560397416.length == 0) {
#                     cell_1560397416 = link_1560397416.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1560397416 = cell_1560397416.children("div.input");
#                 if (input_1560397416.length == 0) {
#                     input_1560397416 = cell_1560397416.prev("div.nbinput");
#                 }
#                 input_1560397416.hide();
#
#                 toggle_input_1560397416 = function() {
#                     if (input_1560397416.is(':hidden')) {
#                         input_1560397416.slideDown();
#                         link_1560397416[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1560397416.slideUp();
#                         link_1560397416[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="2125653834" href="javascript:toggle_input_2125653834()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2125653834;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2125653834 = document.getElementById("2125653834");
#                 var cell = link_2125653834;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2125653834;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2125653834 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2125653834 = cell.previousElementSibling;
#                 }
#                 input_2125653834.style.display = "none"; // hide
#
#                 toggle_input_2125653834 = function() {
#                     if (input_2125653834.style.display == "none") {
#                         input_2125653834.style.display = ""; // show
#                         link_2125653834.innerHTML = "Hide Input";
#                     } else {
#                         input_2125653834.style.display = "none"; // hide
#                         link_2125653834.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2125653834 = $("a[id='2125653834']");
#                 var cell_2125653834 = link_2125653834.parents("div.cell:first");
#                 if (cell_2125653834.length == 0) {
#                     cell_2125653834 = link_2125653834.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2125653834 = cell_2125653834.children("div.input");
#                 if (input_2125653834.length == 0) {
#                     input_2125653834 = cell_2125653834.prev("div.nbinput");
#                 }
#                 input_2125653834.hide();
#
#                 toggle_input_2125653834 = function() {
#                     if (input_2125653834.is(':hidden')) {
#                         input_2125653834.slideDown();
#                         link_2125653834[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2125653834.slideUp();
#                         link_2125653834[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="443805709" href="javascript:toggle_input_443805709()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_443805709;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_443805709 = document.getElementById("443805709");
#                 var cell = link_443805709;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_443805709;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_443805709 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_443805709 = cell.previousElementSibling;
#                 }
#                 input_443805709.style.display = "none"; // hide
#
#                 toggle_input_443805709 = function() {
#                     if (input_443805709.style.display == "none") {
#                         input_443805709.style.display = ""; // show
#                         link_443805709.innerHTML = "Hide Input";
#                     } else {
#                         input_443805709.style.display = "none"; // hide
#                         link_443805709.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_443805709 = $("a[id='443805709']");
#                 var cell_443805709 = link_443805709.parents("div.cell:first");
#                 if (cell_443805709.length == 0) {
#                     cell_443805709 = link_443805709.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_443805709 = cell_443805709.children("div.input");
#                 if (input_443805709.length == 0) {
#                     input_443805709 = cell_443805709.prev("div.nbinput");
#                 }
#                 input_443805709.hide();
#
#                 toggle_input_443805709 = function() {
#                     if (input_443805709.is(':hidden')) {
#                         input_443805709.slideDown();
#                         link_443805709[0].innerHTML = "Hide Input";
#                     } else {
#                         input_443805709.slideUp();
#                         link_443805709[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1758061892" href="javascript:toggle_input_1758061892()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1758061892;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1758061892 = document.getElementById("1758061892");
#                 var cell = link_1758061892;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1758061892;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1758061892 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1758061892 = cell.previousElementSibling;
#                 }
#                 input_1758061892.style.display = "none"; // hide
#
#                 toggle_input_1758061892 = function() {
#                     if (input_1758061892.style.display == "none") {
#                         input_1758061892.style.display = ""; // show
#                         link_1758061892.innerHTML = "Hide Input";
#                     } else {
#                         input_1758061892.style.display = "none"; // hide
#                         link_1758061892.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1758061892 = $("a[id='1758061892']");
#                 var cell_1758061892 = link_1758061892.parents("div.cell:first");
#                 if (cell_1758061892.length == 0) {
#                     cell_1758061892 = link_1758061892.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1758061892 = cell_1758061892.children("div.input");
#                 if (input_1758061892.length == 0) {
#                     input_1758061892 = cell_1758061892.prev("div.nbinput");
#                 }
#                 input_1758061892.hide();
#
#                 toggle_input_1758061892 = function() {
#                     if (input_1758061892.is(':hidden')) {
#                         input_1758061892.slideDown();
#                         link_1758061892[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1758061892.slideUp();
#                         link_1758061892[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="718147618" href="javascript:toggle_input_718147618()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_718147618;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_718147618 = document.getElementById("718147618");
#                 var cell = link_718147618;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_718147618;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_718147618 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_718147618 = cell.previousElementSibling;
#                 }
#                 input_718147618.style.display = "none"; // hide
#
#                 toggle_input_718147618 = function() {
#                     if (input_718147618.style.display == "none") {
#                         input_718147618.style.display = ""; // show
#                         link_718147618.innerHTML = "Hide Input";
#                     } else {
#                         input_718147618.style.display = "none"; // hide
#                         link_718147618.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_718147618 = $("a[id='718147618']");
#                 var cell_718147618 = link_718147618.parents("div.cell:first");
#                 if (cell_718147618.length == 0) {
#                     cell_718147618 = link_718147618.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_718147618 = cell_718147618.children("div.input");
#                 if (input_718147618.length == 0) {
#                     input_718147618 = cell_718147618.prev("div.nbinput");
#                 }
#                 input_718147618.hide();
#
#                 toggle_input_718147618 = function() {
#                     if (input_718147618.is(':hidden')) {
#                         input_718147618.slideDown();
#                         link_718147618[0].innerHTML = "Hide Input";
#                     } else {
#                         input_718147618.slideUp();
#                         link_718147618[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="130659073" href="javascript:toggle_input_130659073()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_130659073;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_130659073 = document.getElementById("130659073");
#                 var cell = link_130659073;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_130659073;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_130659073 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_130659073 = cell.previousElementSibling;
#                 }
#                 input_130659073.style.display = "none"; // hide
#
#                 toggle_input_130659073 = function() {
#                     if (input_130659073.style.display == "none") {
#                         input_130659073.style.display = ""; // show
#                         link_130659073.innerHTML = "Hide Input";
#                     } else {
#                         input_130659073.style.display = "none"; // hide
#                         link_130659073.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_130659073 = $("a[id='130659073']");
#                 var cell_130659073 = link_130659073.parents("div.cell:first");
#                 if (cell_130659073.length == 0) {
#                     cell_130659073 = link_130659073.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_130659073 = cell_130659073.children("div.input");
#                 if (input_130659073.length == 0) {
#                     input_130659073 = cell_130659073.prev("div.nbinput");
#                 }
#                 input_130659073.hide();
#
#                 toggle_input_130659073 = function() {
#                     if (input_130659073.is(':hidden')) {
#                         input_130659073.slideDown();
#                         link_130659073[0].innerHTML = "Hide Input";
#                     } else {
#                         input_130659073.slideUp();
#                         link_130659073[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1801132266" href="javascript:toggle_input_1801132266()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1801132266;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1801132266 = document.getElementById("1801132266");
#                 var cell = link_1801132266;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1801132266;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1801132266 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1801132266 = cell.previousElementSibling;
#                 }
#                 input_1801132266.style.display = "none"; // hide
#
#                 toggle_input_1801132266 = function() {
#                     if (input_1801132266.style.display == "none") {
#                         input_1801132266.style.display = ""; // show
#                         link_1801132266.innerHTML = "Hide Input";
#                     } else {
#                         input_1801132266.style.display = "none"; // hide
#                         link_1801132266.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1801132266 = $("a[id='1801132266']");
#                 var cell_1801132266 = link_1801132266.parents("div.cell:first");
#                 if (cell_1801132266.length == 0) {
#                     cell_1801132266 = link_1801132266.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1801132266 = cell_1801132266.children("div.input");
#                 if (input_1801132266.length == 0) {
#                     input_1801132266 = cell_1801132266.prev("div.nbinput");
#                 }
#                 input_1801132266.hide();
#
#                 toggle_input_1801132266 = function() {
#                     if (input_1801132266.is(':hidden')) {
#                         input_1801132266.slideDown();
#                         link_1801132266[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1801132266.slideUp();
#                         link_1801132266[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="260885516" href="javascript:toggle_input_260885516()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_260885516;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_260885516 = document.getElementById("260885516");
#                 var cell = link_260885516;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_260885516;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_260885516 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_260885516 = cell.previousElementSibling;
#                 }
#                 input_260885516.style.display = "none"; // hide
#
#                 toggle_input_260885516 = function() {
#                     if (input_260885516.style.display == "none") {
#                         input_260885516.style.display = ""; // show
#                         link_260885516.innerHTML = "Hide Input";
#                     } else {
#                         input_260885516.style.display = "none"; // hide
#                         link_260885516.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_260885516 = $("a[id='260885516']");
#                 var cell_260885516 = link_260885516.parents("div.cell:first");
#                 if (cell_260885516.length == 0) {
#                     cell_260885516 = link_260885516.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_260885516 = cell_260885516.children("div.input");
#                 if (input_260885516.length == 0) {
#                     input_260885516 = cell_260885516.prev("div.nbinput");
#                 }
#                 input_260885516.hide();
#
#                 toggle_input_260885516 = function() {
#                     if (input_260885516.is(':hidden')) {
#                         input_260885516.slideDown();
#                         link_260885516[0].innerHTML = "Hide Input";
#                     } else {
#                         input_260885516.slideUp();
#                         link_260885516[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1650307620" href="javascript:toggle_input_1650307620()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1650307620;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1650307620 = document.getElementById("1650307620");
#                 var cell = link_1650307620;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1650307620;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1650307620 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1650307620 = cell.previousElementSibling;
#                 }
#                 input_1650307620.style.display = "none"; // hide
#
#                 toggle_input_1650307620 = function() {
#                     if (input_1650307620.style.display == "none") {
#                         input_1650307620.style.display = ""; // show
#                         link_1650307620.innerHTML = "Hide Input";
#                     } else {
#                         input_1650307620.style.display = "none"; // hide
#                         link_1650307620.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1650307620 = $("a[id='1650307620']");
#                 var cell_1650307620 = link_1650307620.parents("div.cell:first");
#                 if (cell_1650307620.length == 0) {
#                     cell_1650307620 = link_1650307620.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1650307620 = cell_1650307620.children("div.input");
#                 if (input_1650307620.length == 0) {
#                     input_1650307620 = cell_1650307620.prev("div.nbinput");
#                 }
#                 input_1650307620.hide();
#
#                 toggle_input_1650307620 = function() {
#                     if (input_1650307620.is(':hidden')) {
#                         input_1650307620.slideDown();
#                         link_1650307620[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1650307620.slideUp();
#                         link_1650307620[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="534330555" href="javascript:toggle_input_534330555()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_534330555;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_534330555 = document.getElementById("534330555");
#                 var cell = link_534330555;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_534330555;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_534330555 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_534330555 = cell.previousElementSibling;
#                 }
#                 input_534330555.style.display = "none"; // hide
#
#                 toggle_input_534330555 = function() {
#                     if (input_534330555.style.display == "none") {
#                         input_534330555.style.display = ""; // show
#                         link_534330555.innerHTML = "Hide Input";
#                     } else {
#                         input_534330555.style.display = "none"; // hide
#                         link_534330555.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_534330555 = $("a[id='534330555']");
#                 var cell_534330555 = link_534330555.parents("div.cell:first");
#                 if (cell_534330555.length == 0) {
#                     cell_534330555 = link_534330555.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_534330555 = cell_534330555.children("div.input");
#                 if (input_534330555.length == 0) {
#                     input_534330555 = cell_534330555.prev("div.nbinput");
#                 }
#                 input_534330555.hide();
#
#                 toggle_input_534330555 = function() {
#                     if (input_534330555.is(':hidden')) {
#                         input_534330555.slideDown();
#                         link_534330555[0].innerHTML = "Hide Input";
#                     } else {
#                         input_534330555.slideUp();
#                         link_534330555[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="517435631" href="javascript:toggle_input_517435631()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_517435631;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_517435631 = document.getElementById("517435631");
#                 var cell = link_517435631;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_517435631;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_517435631 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_517435631 = cell.previousElementSibling;
#                 }
#                 input_517435631.style.display = "none"; // hide
#
#                 toggle_input_517435631 = function() {
#                     if (input_517435631.style.display == "none") {
#                         input_517435631.style.display = ""; // show
#                         link_517435631.innerHTML = "Hide Input";
#                     } else {
#                         input_517435631.style.display = "none"; // hide
#                         link_517435631.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_517435631 = $("a[id='517435631']");
#                 var cell_517435631 = link_517435631.parents("div.cell:first");
#                 if (cell_517435631.length == 0) {
#                     cell_517435631 = link_517435631.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_517435631 = cell_517435631.children("div.input");
#                 if (input_517435631.length == 0) {
#                     input_517435631 = cell_517435631.prev("div.nbinput");
#                 }
#                 input_517435631.hide();
#
#                 toggle_input_517435631 = function() {
#                     if (input_517435631.is(':hidden')) {
#                         input_517435631.slideDown();
#                         link_517435631[0].innerHTML = "Hide Input";
#                     } else {
#                         input_517435631.slideUp();
#                         link_517435631[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="387922153" href="javascript:toggle_input_387922153()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_387922153;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_387922153 = document.getElementById("387922153");
#                 var cell = link_387922153;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_387922153;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_387922153 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_387922153 = cell.previousElementSibling;
#                 }
#                 input_387922153.style.display = "none"; // hide
#
#                 toggle_input_387922153 = function() {
#                     if (input_387922153.style.display == "none") {
#                         input_387922153.style.display = ""; // show
#                         link_387922153.innerHTML = "Hide Input";
#                     } else {
#                         input_387922153.style.display = "none"; // hide
#                         link_387922153.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_387922153 = $("a[id='387922153']");
#                 var cell_387922153 = link_387922153.parents("div.cell:first");
#                 if (cell_387922153.length == 0) {
#                     cell_387922153 = link_387922153.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_387922153 = cell_387922153.children("div.input");
#                 if (input_387922153.length == 0) {
#                     input_387922153 = cell_387922153.prev("div.nbinput");
#                 }
#                 input_387922153.hide();
#
#                 toggle_input_387922153 = function() {
#                     if (input_387922153.is(':hidden')) {
#                         input_387922153.slideDown();
#                         link_387922153[0].innerHTML = "Hide Input";
#                     } else {
#                         input_387922153.slideUp();
#                         link_387922153[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="1072714335" href="javascript:toggle_input_1072714335()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1072714335;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1072714335 = document.getElementById("1072714335");
#                 var cell = link_1072714335;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1072714335;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1072714335 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1072714335 = cell.previousElementSibling;
#                 }
#                 input_1072714335.style.display = "none"; // hide
#
#                 toggle_input_1072714335 = function() {
#                     if (input_1072714335.style.display == "none") {
#                         input_1072714335.style.display = ""; // show
#                         link_1072714335.innerHTML = "Hide Input";
#                     } else {
#                         input_1072714335.style.display = "none"; // hide
#                         link_1072714335.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1072714335 = $("a[id='1072714335']");
#                 var cell_1072714335 = link_1072714335.parents("div.cell:first");
#                 if (cell_1072714335.length == 0) {
#                     cell_1072714335 = link_1072714335.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1072714335 = cell_1072714335.children("div.input");
#                 if (input_1072714335.length == 0) {
#                     input_1072714335 = cell_1072714335.prev("div.nbinput");
#                 }
#                 input_1072714335.hide();
#
#                 toggle_input_1072714335 = function() {
#                     if (input_1072714335.is(':hidden')) {
#                         input_1072714335.slideDown();
#                         link_1072714335[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1072714335.slideUp();
#                         link_1072714335[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
